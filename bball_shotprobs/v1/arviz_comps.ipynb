# %%
import cloudpickle
import pandas as pd
import numpy as np
from tqdm import tqdm

import pymc as pm
import arviz as az
import arviz_plots as azp
import xarray as xr
RANDOM_SEED = 694973

np.random.seed(RANDOM_SEED)
pd.set_option('display.max_columns', None)

# %%
def compute_log_likelihood(model: pm.Model, trace: az.InferenceData) -> None:
    """Wrapper to compute elemwise log_likelihood of model given InferenceData with posterior group
    Args:
        model (pm.Model): A PyMC model object
        trace (az.InferenceData): Results from sampling
    """
    with model:
        pm.compute_log_likelihood(trace)
    return None

# %%
with open("models_pkl/shot_type.pkl", "rb") as f:
    model = cloudpickle.load(f)

# %%
trace = az.from_netcdf("trace_objects/shottype.nc")

# %%
compute_log_likelihood(model, trace)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.loo(trace, var_name='shot_lkhood')
# Out:
# Computed from 6000 posterior samples and 497034 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -321218.89   199.82
# p_loo        5.04        -
# ------
#
# Pareto k diagnostic values:
#                           Count   Pct.
# (-Inf, 0.70]   (good)     497034  100.0%
#    (0.70, 1]   (bad)           0    0.0%
#    (1, Inf)   (very bad)      0    0.0%

# %%
az.waic(trace, var_name='shot_lkhood')
# Out:
# Computed from 6000 posterior samples and 497034 observations log-likelihood matrix.
#
#           Estimate       SE
# elpd_waic -321218.89   199.82
# p_waic        5.04        -

# %%
del trace

# %%
with open("models_pkl/player.pkl", "rb") as f:
    model = cloudpickle.load(f)

# %%
trace_player = az.from_netcdf("trace_objects/player.nc")

# %%
compute_log_likelihood(model, trace_player)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.loo(trace_player, var_name='shot_lkhood')
# Out:
# Computed from 6000 posterior samples and 497034 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -320288.80   203.52
# p_loo     1600.42        -
# ------
#
# Pareto k diagnostic values:
#                           Count   Pct.
# (-Inf, 0.70]   (good)     497034  100.0%
#    (0.70, 1]   (bad)           0    0.0%
#    (1, Inf)   (very bad)      0    0.0%

# %%
del trace_player

# %%
with open("models_pkl/def.pkl", "rb") as f:
    model = cloudpickle.load(f)

# %%
trace_def = az.from_netcdf("trace_objects/def.nc")

# %%
compute_log_likelihood(model, trace_def)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.loo(trace_def, var_name='shot_lkhood')
# Out:
# Computed from 6000 posterior samples and 497034 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -319901.14   204.99
# p_loo     1756.51        -
# ------
#
# Pareto k diagnostic values:
#                           Count   Pct.
# (-Inf, 0.70]   (good)     497034  100.0%
#    (0.70, 1]   (bad)           0    0.0%
#    (1, Inf)   (very bad)      0    0.0%

# %%
del trace_def

# %%
# rw tight
with open("models_pkl/tight.pkl", "rb") as f:
    model = cloudpickle.load(f)

# %%
trace_rw_tight = az.from_netcdf("trace_objects/trace_hier_rw_tight.nc")

# %%
compute_log_likelihood(model, trace_rw_tight)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.loo(trace_rw_tight, var_name='shot_lkhood')
# Out:
# Computed from 6000 posterior samples and 497034 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -319626.92   205.95
# p_loo     1288.93        -
# ------
#
# Pareto k diagnostic values:
#                           Count   Pct.
# (-Inf, 0.70]   (good)     497034  100.0%
#    (0.70, 1]   (bad)           0    0.0%
#    (1, Inf)   (very bad)      0    0.0%

# %%
del trace_rw_tight

# %%
# rw wide
with open("models_pkl/wide.pkl", "rb") as f:
    model = cloudpickle.load(f)

# %%
trace_rw_wide = az.from_netcdf("trace_objects/trace_hier_rw_wide.nc")

# %%
compute_log_likelihood(model, trace_rw_wide)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.loo(trace_rw_wide, var_name='shot_lkhood')
# Out:
# Computed from 6000 posterior samples and 497034 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -319628.18   205.96
# p_loo     1291.12        -
# ------
#
# Pareto k diagnostic values:
#                           Count   Pct.
# (-Inf, 0.70]   (good)     497034  100.0%
#    (0.70, 1]   (bad)           0    0.0%
#    (1, Inf)   (very bad)      0    0.0%

# %%
del trace_rw_wide

# %%
# rw exp
with open("models_pkl/exp.pkl", "rb") as f:
    model = cloudpickle.load(f)

# %%
trace_rw_exp = az.from_netcdf("trace_objects/trace_hier_rw_exp.nc")

# %%
compute_log_likelihood(model, trace_rw_exp)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.loo(trace_rw_exp, var_name='shot_lkhood')
# Out:
# Computed from 6000 posterior samples and 497034 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -319627.62   205.94
# p_loo     1288.23        -
# ------
#
# Pareto k diagnostic values:
#                           Count   Pct.
# (-Inf, 0.70]   (good)     497034  100.0%
#    (0.70, 1]   (bad)           0    0.0%
#    (1, Inf)   (very bad)      0    0.0%
