# %% [markdown]
# # Modeling Latent 90th percentile Exit Velocity and Imputing Missing Bat Speed Data
#
# We first model latent EV90 and then impute missing bat speeds. Much of what follows is from the original paper posted.

# %%
from typing import Tuple
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error

import pymc as pm
import pytensor.tensor as pt
import arviz as az
import arviz_plots as azp
import xarray as xr

import matplotlib.pyplot as plt
from matplotlib import gridspec
from scipy.stats import gaussian_kde

RANDOM_SEED = 457775 # https://www.reddit.com/r/baseball/comments/b5vfik/whos_the_most_random_mlb_player_you_can_think_of/
np.random.seed(RANDOM_SEED)

# for reproducibility
print("pandas: "+pd.__version__)
print("numpy: "+np.__version__)
print("pymc: "+pm.__version__)
import sklearn
print("sklearn: "+sklearn.__version__)
import pytensor
print("pytensor: "+pytensor.__version__)
print("arviz: "+az.__version__)
print("arviz_plots: "+azp.__version__)
# Out:
# pandas: 3.0.5
# numpy: 2.4.3
# pymc: 6.2.0
# sklearn: 1.9.0
# pytensor: 3.2.4
# arviz: 1.3.0
# arviz_plots: 1.3.0

# %%
df = pd.read_csv('data/agg_data_month.csv')
df['bam_id'] = pd.to_numeric(df['bam_id'], errors='coerce')
df[['bips','ev90']].loc[df['ev90']<95]['bips'].describe()
# Out:
# count    1591.000000
# mean        7.625393
# std        11.702248
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         8.000000
# max       106.000000
# Name: bips, dtype: float64

# %% [markdown]
# Here we define an index function that takes some input and maps it to 0 to n-1. This will be used by the model to help index the data and essentially label it for the model.

# %%
# first use handy index function
def define_index(data: pd.DataFrame, label: str) -> Tuple[np.array, dict]:
    """Defines an index variable starting at 0.
    Args:
        data (pd.DataFrame): dataframe with values to index
        label (str): column name user wishes to index in string format

    Returns:
        Union[
            np.array: indexed values
            dict: dictionary mapping the input values and their indexed values
            ]
    """
    unq_ids = data[label].astype(str).unique()
    lookup = {v: i for i, v in enumerate(unq_ids)}
    index_vals = data[label].astype(str).map(lookup).values.astype("int32")
    return index_vals, lookup

def map_index(data: pd.DataFrame, label: str, lookup_dict: dict) -> np.array:
    """Applies an index to new values
    Args:
        data (pd.DataFrame): dataframe with values to index
        label (str): column name user wishes to index in string format
        lookup_dict (dict): dictionary that contains the mappings from inputs to index

    Returns:
        np.array: indexed values
    """
    s = data[label].astype(str)
    vals = s.map(lookup_dict).values
    return vals

# %%
# Here we are just apply the index function

# seasonal and month
df['time_lbl'] = df['year'].astype(str) + "-" + df['month_name'].astype(str)
time_list = df[['time_index', 'time_lbl']].drop_duplicates().sort_values('time_index')['time_lbl'].tolist()
time_index_vals = df['time_index'].values.astype("int32")

# player index
df['player_full_id'] = df['full'] + " (" + df['bam_id'].astype(str) + ")"
player_name_list = pd.unique(df['player_full_id']).tolist()
df["player_idx"], player_lookup = define_index(df, "player_full_id")
player_index_vals = df['player_idx'].values.astype("int32")

# Note the new columns at the end of the dataframe
df.tail(5)
# Out:
#        bam_id  year month_name  time_index  bips    ev90   ev50     ev_avg  \
# 40919  823550  2026        Aug          64  11.0   96.60  83.90  85.572727
# 40920  828599  2026    Mar/Apr          60   NaN     NaN    NaN        NaN
# 40921  828599  2026        May          61   NaN     NaN    NaN        NaN
# 40922  828599  2026        Jun          62   NaN     NaN    NaN        NaN
# 40923  828599  2026        Jul          63  22.0  106.69  91.95  92.727273
#
#        swing_total  bat_speed  ...    last bats  birth_date position  \
# 40919         29.0  71.758621  ...    Song    L  1996-08-29       2B
# 40920          NaN        NaN  ...  Spence    L  2003-01-27       CF
# 40921          NaN        NaN  ...  Spence    L  2003-01-27       CF
# 40922          NaN        NaN  ...  Spence    L  2003-01-27       CF
# 40923         74.0  72.075676  ...  Spence    L  2003-01-27       CF
#
#       position_group position_hybrid        age      time_lbl  \
# ...

# %%
# These are some generic helper functions to help sample for the model
def sample(model: pm.Model, draws: int = 2000, tune: int = 2000, chains: int = 4, target_accept: float = 0.99, random_seed: int = RANDOM_SEED, path:str = 'temp.nc', **kwargs):
    """
    Fit model using MCMC.

    Parameters
    ----------
    model: pm.Model
        PyMC model object.
    draws : int
        Number of draws to keep from the sampling process.
    tune : int
        Number of tuning steps to take before sampling.
    chains : int
        Number of chains to sample.
    target_accept : float
        Target acceptance probability for step size adaptation.
    random_seed : int
        Seed for randomness.
    """
    with model:
        trace = pm.sample(
            draws=draws,
            tune=tune,
            chains=chains,
            target_accept=target_accept,
            random_seed=random_seed,
            idata_kwargs={"log_likelihood": False}
        )
    try:
        xr.DataTree.to_netcdf(trace, path)
    except Exception as e:
        print(f"Error saving trace to {path}: {e}")
    return trace

def compute_log_likelihood(model: pm.Model, trace: az.InferenceData) -> None:
    """Wrapper to compute elemwise log_likelihood of model given InferenceData with posterior group
    Args:
        model (pm.Model): A PyMC model object
        trace (az.InferenceData): Results from sampling
    """
    with model:
        pm.compute_log_likelihood(trace)
    return None

def sample_posterior_pred(model: pm.Model, trace: az.InferenceData) -> az.InferenceData:
    """Generates samples from the posterior predictive distribution for model checks

    Args:
        model (pm.Model): A PyMC model object
        trace (az.InferenceData): Results from sampling

    Returns:
        az.InferenceData: An ArviZ InferenceData object containing the posterior predictive samples.
    """
    with model:
        spp = pm.sample_posterior_predictive(
            trace,
            extend_inferencedata=True,
            random_seed=RANDOM_SEED,
        )
    return spp
# Out:
# /home/jr/anaconda3/envs/pie/lib/python3.12/site-packages/arviz/__init__.py:110: MigrationWarning: arviz.InferenceData is no longer available on the arviz package; ArviZ now uses xarray's DataTree for the same role. See the migration guide: https://python.arviz.org/en/latest/user_guide/migration_guide.html#datatree
#   warnings.warn(

# %% [markdown]
# Prior to running the model, we define some empirical means and standard deviations to help our priors.

# %%
# empirical means
emp_means = np.array([df['ev90'].mean(), df['bat_speed'].mean()])
emp_stds = np.array([df['ev90'].std(), df['bat_speed'].std()])

print(emp_means)
print(emp_stds)

ev90_obs_mean = emp_means[0]
ev90_obs_std = emp_stds[0]

# main data
n_obs = len(df)
ev90_values = df['ev90'].values.astype(float)
bips_values = df['bips'].values.astype(float)

ev90_mask = ~np.isnan(ev90_values) # mask missing ev90 values
ev90_index_vals = np.where(ev90_mask)[0].astype("int32") # indices of observed ev90 values
ev90_observed = ev90_values[ev90_index_vals] 

bips_observed = np.clip(bips_values[ev90_index_vals], 1, 200)
bips_sqrt = np.sqrt(bips_observed)
# Out:
# [102.31658877  70.61438792]
# [4.84455088 2.81934695]

# %% [markdown]
# Here we define our model. The general measurement error model is $x^{obs} \sim N(x^{true}, \epsilon)$, where $x^{obs}$ represents the observed measurement and $x^{true}$ represents the underlying true or latent skill. We extended this framework in two ways. First, we scaled the observation noise by the inverse of BIPs to reflect that monthly estimates with more observations are more reliable. Second, we placed a random walk prior on the latent EV90 to capture within-career change, allowing it to drift over time rather than have each month be independent. Formally, our EV90 measurement error model for a player $p$ at time $t$ is:
#
# $$
# \begin{gather*}
#     \theta^{obs}_{t,p} \sim N(\theta^{true}_{t,p}, \frac{\sigma^2_{\epsilon}}{bips_{t,p}}) \\
#     \theta^{true}_{t,p}|\theta^{true}_{t-1,p} \sim N(\theta^{true}_{t-1,p}, \sigma^2_{month}) \\
#     \theta^{true}_{0,p} \sim N(\mu, \sigma^2_{p}) \\
#     \mu \sim N(\hat{\mu}_{\mu},\hat{\sigma}^2_{\mu}) \\
#     \sigma_{\epsilon} \sim Exp(0.1) \quad \sigma_p \sim Exp(1) \quad
#     \sigma_{month} \sim Exp(3)
# \end{gather*}
# $$
#
# The first equation is our measurement likelihood: observed EV90 is normally distributed around a latent EV90 with variance inversely proportional to BIPs. The second equation is the random walk: latent EV90 evolves as a Gaussian random walk with variance $\sigma^2_{month}$, which defines how much a player's latent EV90 changes month to month. The third equation is the initial state prior: we draw each player's EV90 from a population distribution with mean $\mu$ and between-player variance $\sigma^2_p$. The last line represents our priors. The population mean has an empirical prior based on our observations, and we placed weak exponential priors (rate parameterization) on our variance terms. We chose these priors after performing prior predictive checks and analyzing the distribution of our latent EV90. With priors of $Exp(1)$, the 1st and 99th percentiles were 82 and 122.37. Since 122.37 would be one of the hardest-hit balls on record and the max observed EV90 was around 118, we tightened the priors. Doing so brought the 1st and 99th percentiles of latent EV90 to 86 and 119, respectively. We fit the model using Markov Chain Monte Carlo via the No-U-Turn Sampler (NUTS) in PyMC. After sampling, we assessed convergence via the $\hat{R}$ statistic, with all parameters achieving $\hat{R} \le 1.01$, and through visual checks of the posterior predictive distribution.

# %%
coords = {
    "observation_id": np.arange(n_obs),
    "ev_obs_id": np.arange(len(ev90_index_vals)),
    "time": time_list,
    "time_walk": time_list[1:],
    "player": player_name_list
}

with pm.Model(coords=coords) as model:
    # data
    time_idx = pm.Data("time_idx", time_index_vals, dims=("observation_id",))
    player_idx = pm.Data("player_idx", player_index_vals, dims=("observation_id",))
    ev_obs_idx = pm.Data('ev_idx', ev90_index_vals, dims=("ev_obs_id",))

    # priors
    ## ev90 distribution
    ev90_distribution = pm.Normal('ev90_distribution', mu=ev90_obs_mean, sigma=ev90_obs_std*1.25)
    ## how much do we expect players to vary from the overall mean ev90
    sigma_player = pm.Exponential('sigma_player', 1.0)
    ## month over month change in ev90
    sigma_month = pm.Exponential('sigma_month', scale = 1/3)
    
    # set initial values from N(0,1) dist
    player_init_raw = pm.Normal('player_init_raw', mu=0, sigma=1.0, dims=("player"))
    player_init = pm.Deterministic('player_init', player_init_raw - player_init_raw.mean(), dims="player")
    # player = u_pop + scale*init(0,1)
    player_start = pm.Deterministic('player_start', ev90_distribution + player_init * sigma_player, dims=("player"))
    
    # create matrix of size (n_months_years-1, n_players) of monthly innovations
    # one innovation per player per time step
    month_innovations = pm.Normal('month_innovations', mu=0, sigma=1.0, dims=("time_walk","player"))
    # [0, player],
    # [0+month_innovation_1, player],
    # [0+month_innovation_1+month_innovation_2, player], ...
    walk = pt.concatenate([
        pt.zeros((1, len(coords["player"]))),
        pt.cumsum(month_innovations, axis=0)
    ], axis=0)

    # scale the walk by innovation variance
    monthly_walk = pm.Deterministic('monthly_walk', walk * sigma_month, dims=("time","player"))

    # make player start "first index", then add walk to get innovations over the months
    # [ev90 (from ev90 dist) in month 0, player]
    # [ev90 (from ev90 dist + month_innovation_1), player], ...
    # [ev90 (from ev90 dist + month_innovation_1 + month_innovation_2), player], ...
    theta_ev90 = pm.Deterministic('theta_ev90', player_start[None, :] + monthly_walk, dims=("time","player"))
    theta_ev90_observed = theta_ev90[time_idx, player_idx]

    # lkhood
    ev90_sigma = pm.Exponential('ev90_sigma', scale = 10.0)
    pm.Normal('ev90_lkhood', mu=theta_ev90_observed[ev_obs_idx], sigma=ev90_sigma/bips_sqrt, observed=ev90_observed, dims=("ev_obs_id",))

# %%
with model:
    prior_pred = pm.sample_prior_predictive(draws=500, random_seed=RANDOM_SEED)
# Out:
# Sampling: [ev90_distribution, ev90_lkhood, ev90_sigma, month_innovations, player_init_raw, sigma_month, sigma_player]

# %%
theta_prior = prior_pred.prior["theta_ev90"]
low, high = np.percentile(theta_prior.values, [1, 99])
print(low, high)
# Out:
# 86.04960073928282 119.6263083404661

# %%
df['ev90'].describe(percentiles=[.01, .05, .25, .5, .75, .95, .99])
# Out:
# count    28928.000000
# mean       102.316589
# std          4.844551
# min         65.100000
# 1%          83.445400
# 5%          94.520000
# 25%        100.370000
# 50%        102.900000
# 75%        105.250000
# 95%        108.400000
# 99%        110.647300
# max        118.800000
# Name: ev90, dtype: float64

# %%
# Sample via MCMC and NUTS
trace = sample(model, draws = 1000, tune = 1000, target_accept = 0.99,  path='measure_error.nc')
# Out:
# NUTS[nutpie]: [ev90_distribution, sigma_player, sigma_month, player_init_raw, month_innovations, ev90_sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.summary(trace, var_names=['ev90_distribution','sigma_player','ev90_sigma','sigma_month'], ci_prob=0.95, round_to=2)
# Out:
#                      mean    sd  eti95_lb  eti95_ub  ess_bulk  ess_tail  \
# ev90_distribution  102.31  0.05    102.22    102.40    752.40   1138.30
# sigma_player         2.58  0.06      2.47      2.71    438.24    755.85
# ev90_sigma          12.52  0.06     12.40     12.65   1959.10   2142.39
# sigma_month          0.29  0.01      0.28      0.31    405.20    700.66
#
#                    r_hat  mcse_mean  mcse_sd
# ev90_distribution   1.01        0.0      0.0
# sigma_player        1.00        0.0      0.0
# ev90_sigma          1.00        0.0      0.0
# sigma_month         1.00        0.0      0.0

# %% [markdown]
# After sampling, we check for convergence. The easiest way is inspecting R-hat values and seeing if they are at or below 1.01 for all parameters. Spoiler alert: the model converged. We found the player standard deviation, or how much players differ, was 2.6 mph, and the monthly deviation was 0.3 mph.

# %%
ev_avg_df = az.summary(trace, var_names=['theta_ev90'], ci_prob=0.95, round_to=2).reset_index(drop=False)
ev_avg_df.head()
# Out:
#                                                index    mean    sd  eti95_lb  \
# 0     theta_ev90[2016-Mar/Apr, David Ortiz (120074)]  106.92  0.67    105.58
# 1  theta_ev90[2016-Mar/Apr, Alex Rodriguez (121347)]  105.04  0.97    103.14
# 2   theta_ev90[2016-Mar/Apr, Adrian Beltré (134181)]  102.92  0.59    101.78
# 3  theta_ev90[2016-Mar/Apr, Carlos Beltrán (136860)]  104.04  0.61    102.84
# 4    theta_ev90[2016-Mar/Apr, Jayson Werth (150029)]  105.22  0.65    103.91
#
#    eti95_ub  ess_bulk  ess_tail  r_hat  mcse_mean  mcse_sd
# 0    108.19   3679.82   2914.25    1.0       0.01     0.01
# 1    106.95   5626.50   3117.42    1.0       0.01     0.01
# 2    104.07   2812.26   2790.60    1.0       0.01     0.01
# 3    105.19   2997.38   3023.28    1.0       0.01     0.01
# 4    106.47   3994.04   3528.10    1.0       0.01     0.01

# %%
trace_df = az.summary(trace, var_names=['~theta_ev90'], ci_prob=0.95).reset_index(drop=False)
# Out:
# /home/jr/anaconda3/envs/pie/lib/python3.12/site-packages/arviz_stats/base/diagnostics.py:90: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/jr/anaconda3/envs/pie/lib/python3.12/site-packages/arviz_stats/base/diagnostics.py:313: RuntimeWarning: invalid value encountered in scalar divide
#   varsd = varvar / evar / 4

# %%
print(round(trace_df['r_hat'].max(),2))
# Out:
# 1.01

# %%
trace_df.head()
# Out:
#                                       index        mean        sd   eti95_lb    eti95_ub     ess_bulk     ess_tail     r_hat mcse_mean   mcse_sd
# 0                         ev90_distribution  102.306077  0.045465  102.21787  102.396555    752.39532  1138.299267  1.005682  0.001661  0.001191
# 1     player_init_raw[David Ortiz (120074)]    1.787585  0.263616   1.252391    2.293625  2630.365333  3001.184502   1.00251  0.005146  0.003676
# 2  player_init_raw[Alex Rodriguez (121347)]    1.058903  0.375465    0.32212      1.8118  5427.978518  3105.007147  1.002252  0.005084  0.003553
# 3   player_init_raw[Adrian Beltré (134181)]    0.235919  0.230029  -0.206189    0.691677  2636.675159  2748.813611  1.000107  0.004481  0.003087
# 4  player_init_raw[Carlos Beltrán (136860)]    0.669926  0.236975   0.207871    1.129991    2882.6075  2943.257164   1.00182  0.004414  0.003207

# %% [markdown]
# Here we use `az.plot_energy` as a diagnostic in Bayesian MCMC sampling to compare the marginal energy distribution to the energy transition distribution from the sampler. Our objective is to assess how well the sampler is exploring the posterior, with strong overlap between the two representing efficient exploration of the posterior distribution.

# %%
az.plot_energy(trace)

# %% [markdown]
# Next we used `azp.plot_trace_dist` to see how the chains mix. We only show a few parameters, since displaying each player's distribution in a single graph is not worthwhile. This convergence check evaluates whether the chains are mixing uniformly by comparing the rank distributions of samples across chains. Well-mixed chains should roughly overlap, while divergence or separation indicates poor mixing and non-convergence.

# %%
azp.plot_trace_dist(trace, var_names=['ev90_distribution','sigma_player','ev90_sigma','sigma_month'])

# %%
spp = sample_posterior_pred(model, trace)
# Out:
# Sampling: [ev90_lkhood]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# Lastly, we evaluated the posterior predictive checks using `az.plot_ppc`, which compares the observed data distribution (black line) to data simulated from the posterior predictive distribution (blue curve). Strong overlap between these distributions indicates the model can reproduce the observed data. If the two lines did not overlap, the model would be poorly specified even though it converged.

# %%
pc = azp.plot_ppc_dist(spp, var_names="ev90_lkhood", num_samples=250)
ax = pc.viz["plot"]["ev90_lkhood"].item()
ax.set_xlim(60,120)
ax.set_xlabel("EV90th Likelihood (mph)")
# Out:
# Text(0.5, 0, 'EV90th Likelihood (mph)')

# %%
# rip off the latent value sampled and append to dataframe
theta_samples = trace.posterior['theta_ev90']
theta_matrix_mean = theta_samples.mean(dim=["chain", "draw"]).values
theta_matrix_std = theta_samples.std(dim=["chain", "draw"]).values
df['latent_ev90_mean'] = theta_matrix_mean[time_index_vals, player_index_vals]
df['latent_ev90_std'] = theta_matrix_std[time_index_vals, player_index_vals]

# %%
df.tail()
# Out:
#        bam_id  year month_name  time_index  bips    ev90   ev50     ev_avg  \
# 40919  823550  2026        Aug          64  11.0   96.60  83.90  85.572727
# 40920  828599  2026    Mar/Apr          60   NaN     NaN    NaN        NaN
# 40921  828599  2026        May          61   NaN     NaN    NaN        NaN
# 40922  828599  2026        Jun          62   NaN     NaN    NaN        NaN
# 40923  828599  2026        Jul          63  22.0  106.69  91.95  92.727273
#
#        swing_total  bat_speed  ...  birth_date position position_group  \
# 40919         29.0  71.758621  ...  1996-08-29       2B        Defense
# 40920          NaN        NaN  ...  2003-01-27       CF        Defense
# 40921          NaN        NaN  ...  2003-01-27       CF        Defense
# 40922          NaN        NaN  ...  2003-01-27       CF        Defense
# 40923         74.0  72.075676  ...  2003-01-27       CF        Defense
#
#       position_hybrid        age      time_lbl          player_full_id  \
# ...

# %% [markdown]
# After confirming the model was sufficent, we compared the latent EV90 with the observed EV90.

# %%
# make ev_avg dataframe with index columns
cdf = df.copy()
cdf['diff'] = cdf['ev90'] - cdf['latent_ev90_mean']
cdf.head(10)
# Out:
#    bam_id  year month_name  time_index  bips    ev90  ev50     ev_avg  \
# 0  120074  2016    Mar/Apr           0  62.0  107.51  95.7  94.625806
# 1  120074  2016        May           1  78.0  108.94  96.7  93.708974
# 2  120074  2016        Jun           2  73.0  105.84  93.5  92.479452
# 3  120074  2016        Jul           3  76.0  106.45  92.7  92.730263
# 4  120074  2016        Aug           4  79.0  107.94  96.8  92.731646
# 5  120074  2016    Sep/Oct           5  76.0  106.25  93.0  93.082895
# 6  121347  2016    Mar/Apr           0  45.0  108.66  93.9  92.302222
# 7  121347  2016        May           1  13.0  106.50  89.6  89.546154
# 8  121347  2016        Jun           2  67.0  104.62  91.0  88.562687
# 9  121347  2016        Jul           3  27.0  103.16  94.0  89.929630
#
#    swing_total  bat_speed  ... position position_group position_hybrid  \
# 0        168.0        NaN  ...       DH          Power              DH
# ...

# %%
g = cdf.groupby('bips').agg(
    ev_diff=('diff', 'mean'),
    ev_diff_sd=('diff', 'std'),
    ss=('diff','count')
).reset_index(drop=False)

plt.plot(g['bips'], g['ev_diff'])
plt.fill_between(g['bips'],  g['ev_diff']-g["ev_diff_sd"],  g['ev_diff']+g["ev_diff_sd"], alpha=0.2, color='blue')
plt.xlabel('BIPs')
plt.ylim(-25,10)
plt.ylabel('Obs EV90 minus Latent EV90')
plt.title('Difference between Obs EV90 and Latent EV90')
plt.grid(True)

# %%
df.loc[df['bips']>=115]
# Out:
#        bam_id  year month_name  time_index   bips    ev90  ev50     ev_avg  \
# 13759  592518  2017        Aug          10  117.0  106.60  92.7  89.503419
# 26188  650333  2024    Mar/Apr          48  116.0   97.60  89.9  86.159483
# 26196  650333  2025        Jun          56  115.0   96.40  86.6  85.453043
# 28415  660757  2022    Sep/Oct          41  117.0  104.64  90.2  87.483761
# 36036  676391  2026    Mar/Apr          60  116.0   99.90  88.3  86.368103
# 37355  680757  2022    Sep/Oct          41  122.0   99.80  87.5  86.235246
#
#        swing_total  bat_speed  ...  birth_date position position_group  \
# 13759        245.0        NaN  ...  1992-07-06       3B          Power
# 26188        162.0  61.781481  ...  1997-04-09       2B        Defense
# 26196        208.0  61.724038  ...  1997-04-09       2B        Defense
# 28415        303.0        NaN  ...  1998-01-10       RF          Power
# 36036        199.0  66.208040  ...  1996-03-22       2B        Defense
# ...

# %%
ev90_sigma_mean = trace.posterior['ev90_sigma'].mean(dim=["chain", "draw"]).values

# %%
# function to plot observed performance coupled with latent value
def plot_performance(df: pd.DataFrame, bam_id: int, ax=None, yticks=np.arange(75, 121, 5)):
    d = df.loc[df["bam_id"] == bam_id].reset_index()
    d_valid = d[d["ev90"].notna()]
    d = d[(d["time_index"] >= d_valid["time_index"].min()-1) & (d["time_index"] <= d_valid["time_index"].max()+1)]
    name = d['full'].iloc[0] + "\n" + str(bam_id) + ""

    if ax is None:
        _, ax = plt.subplots(1, 1, figsize=(15, 4))
    ax.scatter(d['time_index'], d['ev90'], color='red', label='Observed')
    ax.errorbar(d["time_index"], d["ev90"], yerr=ev90_sigma_mean/np.sqrt(d["bips"]), fmt='none', color='red')
    ax.plot(d["time_index"], d["latent_ev90_mean"], color='blue', label='Latent')
    ax.fill_between(d["time_index"], d["latent_ev90_mean"]-1.96*d["latent_ev90_std"], d["latent_ev90_mean"]+1.96*d["latent_ev90_std"], alpha=0.2, color='blue')

    n = len(d)
    step = max(1, n // 20)
    tick_idx = d["time_index"].iloc[::step]
    tick_lbl = d["time_lbl"].iloc[::step]

    ax.set_xticks(tick_idx)
    lbsl = [lbl.replace("-", "\n") for lbl in tick_lbl]
    ax.set_xticklabels(lbsl, rotation=35, fontsize=8)
    ax.set_ylabel('EV90 (mph)')
    ax.set_yticks(yticks)
    ax.grid(True)
    ax.set_title(name, fontsize=14)
    return ax

# %% [markdown]
# Now we plot some players to compare their observed EV90 (red) to their latent EV90 (blue). These players were hand-picked after looking at the data. The latent EV90 really comes into play for players with sparse months of data. We added red error bars representing the observed standard deviation of EV90 divided by the square root of their BIPs, and shaded the latent EV90's standard deviation. Months with sparse data will have longer red bars.

# %%
plot_performance(cdf, 666176, yticks=np.arange(95, 121, 5))
# Out:
# <Axes: title={'center': 'Jo Adell\n666176'}, ylabel='EV90 (mph)'>

# %%
plot_performance(cdf, 663897, yticks=np.arange(70, 111, 5))
# Out:
# <Axes: title={'center': 'Luke Williams\n663897'}, ylabel='EV90 (mph)'>

# %%
# JT has a much more stable latent EV90 that mirrors his observed because he plays more frequently and is better than the two above players.
plot_performance(cdf, 592663, yticks=np.arange(95, 111, 5))
# Out:
# <Axes: title={'center': 'J.T. Realmuto\n592663'}, ylabel='EV90 (mph)'>

# %% [markdown]
# # Missing Bat Speed data

# %%
# here we set up the data
MIN_SWINGS=10
MIN_BIPS=40
cdf['is_complete'] = np.where((cdf['bat_speed'].notnull()) & (cdf['swing_total']>=MIN_SWINGS) & (cdf['bips']>=MIN_BIPS), 1, 0)
complete_mask = cdf['is_complete'] == 1
cdf['bat_speed_complete'] = np.where(complete_mask, cdf['bat_speed'], np.nan)

latent_ev90 = cdf['latent_ev90_mean'].values.astype(float)
bat_speed = cdf['bat_speed'].values.astype(float)
joint_obs = np.stack([latent_ev90[complete_mask], bat_speed[complete_mask]], axis=1).astype(float)
# indices of observed bat speed values with >=MIN_SWINGS and >=MIN_BIPS
complete_index_vals = np.where(complete_mask)[0].astype("int32")

mean_latent_ev90 = latent_ev90.mean()
mean_bat_speed = np.nanmean(bat_speed)
sigma_latent_ev90 = latent_ev90.std()
sigma_bat_speed = np.nanstd(bat_speed)

# %% [markdown]
# We first learned the joint multivariate normal (MvN) between latent EV90 and observed bat speed, restricting to player-months with at least 40 BIPs and at least 10 swings. We chose the 40 BIP threshold because, even though latent EV90 was less noisy than observed EV90, observations with fewer than 40 BIPs still had a larger-than-desired variance. We chose the 10-swing threshold for bat speed based on past experience. Since the missing bat speed data was missing completely at random, we sampled from the MvN of our observed values. In our dataset of monthly observations, the empirical correlation between latent EV90 and observed bat speed was $0.8$, corresponding to an $R^2 = 0.8^2 = 0.64$.
#
# Formally, we model the joint distribution of latent EV90 and bat speed as a multivariate normal:
#
# $$
# \begin{gather*}
# \begin{bmatrix}
# \theta^{true}_i \\
# BS_i
# \end{bmatrix}
# \sim
# N
# \left(
# \begin{bmatrix}
# \mu_\theta \\
# \mu_{BS}
# \end{bmatrix},
# \Sigma
# \right) \\
# \qquad
# \Sigma = LL^T =
# \begin{bmatrix}
# \sigma_\theta^2 & \rho \sigma_\theta \sigma_{BS} \\
# \rho \sigma_\theta \sigma_{BS} & \sigma_{BS}^2
# \end{bmatrix}
# \\
# \mu_{\theta} \sim N(\hat{\mu}_\theta, 1) \quad
# \mu_{BS} \sim N(\hat{\mu}_{BS}, 1) \\
# L \sim \text{LKJCholeskyCov}(\eta=2, \sigma = \hat{\sigma}^2)
# \end{gather*}
# $$

# %%
coords = {
    "complete_obs_id": np.arange(complete_mask.sum()),
    "metric": ['ev90','bat_speed']
}

with pm.Model(coords=coords) as model:
    mu_vec = pm.Normal("mu_vec",
                       mu= np.array([mean_latent_ev90, mean_bat_speed]),
                       sigma = np.array([0.5, 0.5]),
                       shape = 2
    )
    # cholesky
    chol, corr, stds = pm.LKJCholeskyCov("chol", n=2, eta=2.0,
                                            sd_dist=pm.HalfNormal.dist(
                                                sigma=np.array([sigma_latent_ev90, sigma_bat_speed]),
                                                shape=2
                                            )
                                        )
    pm.MvNormal("joint", mu=mu_vec, chol=chol, observed=joint_obs, dims=("complete_obs_id", "metric"))

# %%
trace_mvn = sample(model, draws = 2000, tune = 2000, target_accept = 0.9, path='mvn.nc')
# Out:
# NUTS[nutpie]: [mu_vec, chol]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.summary(trace_mvn, var_names=['mu_vec','chol','chol_corr','chol_stds'], ci_prob=0.95, round_to=2)
# Out:
# /home/jr/anaconda3/envs/pie/lib/python3.12/site-packages/arviz_stats/base/diagnostics.py:90: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
# /home/jr/anaconda3/envs/pie/lib/python3.12/site-packages/arviz_stats/base/diagnostics.py:313: RuntimeWarning: invalid value encountered in scalar divide
#   varsd = varvar / evar / 4
#                    mean    sd  eti95_lb  eti95_ub  ess_bulk  ess_tail  r_hat  \
# mu_vec[0]        104.10  0.04    104.03    104.17   3412.03   4023.78    1.0
# mu_vec[1]         70.86  0.04     70.78     70.93   3369.57   4195.42    1.0
# chol[0]            2.56  0.03      2.51      2.61   4455.60   4888.91    1.0
# chol[1]            2.39  0.03      2.33      2.45   4373.38   4552.96    1.0
# chol[2]            1.36  0.01      1.34      1.39   7780.61   5186.22    1.0
# chol_corr[0, 0]    1.00  0.00      1.00      1.00   8000.00   8000.00    NaN
# ...

# %%
def draw_joint(fig, outer_cell, x, y, xlabel, ylabel, title, xlim=None, ylim=None, xticks=None, yticks=None):
    gs = gridspec.GridSpecFromSubplotSpec(4, 4, subplot_spec=outer_cell, wspace=0.3, hspace=0.45)
    ax_joint = fig.add_subplot(gs[1:4, 0:3])
    ax_marg_x = fig.add_subplot(gs[0, 0:3])
    ax_marg_y = fig.add_subplot(gs[1:4, 3])

    xy = np.vstack([x, y])
    density = gaussian_kde(xy)(xy)

    ax_joint.scatter(x, y, c=density, cmap='viridis')
    m, b = np.polyfit(x, y, 1)
    x_line = np.linspace(x.min(), x.max(), 100)
    ax_joint.plot(x_line, m * x_line + b, color='red', label=f'Corr = {np.corrcoef(x,y)[0,1]:.2f}')
    ax_joint.axline((0, 0), slope=1, color='black', linestyle='--')
    ax_joint.set_xlabel(xlabel)
    ax_joint.set_xlim(xlim)
    ax_joint.set_ylim(ylim)
    ax_joint.set_xticks(xticks)
    ax_joint.set_yticks(yticks)
    ax_joint.set_ylabel(ylabel)
    ax_joint.legend()
    ax_joint.grid(True)
    ax_marg_x.hist(x, bins=100)
    ax_marg_y.hist(y, bins=100, orientation='horizontal')
    ax_marg_x.set_title(title)
    ax_marg_x.set_xticks(xticks)
    ax_marg_y.set_yticks(yticks)

fig = plt.figure(figsize=(8,8))
outer = gridspec.GridSpec(1, 1, figure=fig)

cd1 = df.dropna(subset=['bat_speed', 'latent_ev90_mean']).copy()
cd1 = cd1.loc[(cd1['bips'] >= MIN_BIPS)&(cd1['swing_total'] >= MIN_SWINGS)]
x1, y1 = cd1['latent_ev90_mean'].values.astype(float), cd1['bat_speed'].values.astype(float)

draw_joint(fig, outer[0], x=x1, y=y1, xlabel='Latent EV90 (mph)', ylabel='Bat Speed (mph)',
           title = f'Bat Speed vs Latent EV90 - min {MIN_BIPS} BIPs & min {MIN_SWINGS} Swings',
           xlim = (90,120), ylim = (55,85), xticks = np.arange(90, 121, 5), yticks=np.arange(55, 86, 5)
        )

# %%
# grab posterior distributions
l00_post = trace_mvn.posterior["chol"].values[:,:,0]
l10_post = trace_mvn.posterior["chol"].values[:,:,1]
l11_post = trace_mvn.posterior["chol"].values[:,:,2]
mu_bs_post = trace_mvn.posterior["mu_vec"].values[:,:,1]
mu_ev_post = trace_mvn.posterior["mu_vec"].values[:,:,0]

# weight or beta coefficent
print(round(np.mean(l10_post/l00_post),3))
# Out:
# 0.935

# %% [markdown]
# After sampling, we computed a posterior correlation of 0.87, with a 94% HDI between 0.86 and 0.88. Since sampling from the conditional distribution is analogous to the regression of bat speed on latent EV90, we interpreted $L_{10}/L_{00}=0.93$ as follows: for every 1 mph increase in a player's latent EV90 in a given month, their expected bat speed increases by 0.93 mph, holding all else equal.
#
# For player-months where bat speed is unobserved, we impute by sampling from the conditional distribution. To propagate uncertainty from both the Cholesky factor and the latent EV90, for each posterior draw we first sample the latent EV90 for a player $p$ in time period $t$:
#
# $$\theta^{\text{true}}_{t,p} \sim \mathcal{N}\left(\hat{\theta}^{\text{true}}_{t,p},\ \hat{\sigma}^2_{\theta,t,p}\right)$$
#
# Then, at the observation level, we draw the imputed bat speed:
#
# $$\text{BS}^{\text{imp}}_{i} \sim \mathcal{N}\left(\mu_{\text{BS}} + \frac{L_{10}}{L_{00}}\left(\theta^{\text{true}}_{i} - \mu_\theta\right),\ L^2_{11}\right)$$

# %%
latent_ev90 = cdf['latent_ev90_mean'].values.astype(float)
latent_ev90_std = cdf['latent_ev90_std'].values.astype(float)
rng = np.random.default_rng(RANDOM_SEED)
n_chains = mu_bs_post.shape[0]
n_draws = mu_bs_post.shape[1]
latent_ev90_dist = latent_ev90[None, None, :] + rng.normal(0, 1, size=(n_chains, n_draws, len(latent_ev90))) * latent_ev90_std[None, None, :]
cond_dist = mu_bs_post[:,:,None] + (l10_post/l00_post)[:,:,None]*(latent_ev90_dist - mu_ev_post[:,:,None])
cond_dist = cond_dist + rng.normal(0, l11_post[:,:,None])
cond_mean = cond_dist.mean(axis=(0,1))

cdf['imputed_bat_speed'] = cond_mean
cdf['model_bat_speed'] = np.where(cdf['bat_speed'].isna(),cdf['imputed_bat_speed'], cdf['bat_speed'])
cdf['is_imputed'] = np.where(cdf['bat_speed'].isna(), 1, 0)

cdf.head()
# Out:
#    bam_id  year month_name  time_index  bips    ev90  ev50     ev_avg  \
# 0  120074  2016    Mar/Apr           0  62.0  107.51  95.7  94.625806
# 1  120074  2016        May           1  78.0  108.94  96.7  93.708974
# 2  120074  2016        Jun           2  73.0  105.84  93.5  92.479452
# 3  120074  2016        Jul           3  76.0  106.45  92.7  92.730263
# 4  120074  2016        Aug           4  79.0  107.94  96.8  92.731646
#
#    swing_total  bat_speed  ...        player_full_id player_idx  \
# 0        168.0        NaN  ...  David Ortiz (120074)          0
# 1        193.0        NaN  ...  David Ortiz (120074)          0
# 2        176.0        NaN  ...  David Ortiz (120074)          0
# 3        181.0        NaN  ...  David Ortiz (120074)          0
# 4        180.0        NaN  ...  David Ortiz (120074)          0
#
#   latent_ev90_mean latent_ev90_std      diff is_complete bat_speed_complete  \
# 0       106.923259        0.669996  0.586741           0                NaN
# ...

# %% [markdown]
# To validate the imputation, we computed the root mean squared error between imputed and observed bat speed, which indicated the imputation recovered observed bat speed within 1.36 mph on average. This represents the irreducible uncertainty in bat speed after conditioning on latent EV90, the variation in bat speed among players with the same latent EV90.

# %%
# estimating performance
preds = cdf['imputed_bat_speed'].loc[cdf['is_complete']==1]
true = cdf['bat_speed'].loc[cdf['is_complete']==1]
print(round(mean_squared_error(true, preds),2))
print(round(np.sqrt(mean_squared_error(true, preds)),2))
# Out:
# 1.86
# 1.36

# %%
cdf = cdf[[
    'bam_id','year','month_name','time_index',
    'player_full_id','full','first','last',	'bats',	'birth_date','position','position_group','position_hybrid',
    'age','bips','ev90','latent_ev90_mean','latent_ev90_std',
    'swing_total','bat_speed','imputed_bat_speed',
    'model_bat_speed','is_imputed','is_complete'
]]
cdf = cdf.loc[~((cdf['bips'].isna())&(cdf['swing_total'].isna()))]
cdf.to_csv('data/bat_speed_model_data_monthly.csv',index=False)
